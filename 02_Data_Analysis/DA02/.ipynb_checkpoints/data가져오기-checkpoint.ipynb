# %%
# !wget https://d3s0tskafalll9.cloudfront.net/media/documents/kaggle-kakr-housing-data.zip
# !unzip kaggle-kakr-housing-data.zip -d ./
# Out:
# --2026-06-07 07:57:00--  https://d3s0tskafalll9.cloudfront.net/media/documents/kaggle-kakr-housing-data.zip
# Resolving d3s0tskafalll9.cloudfront.net (d3s0tskafalll9.cloudfront.net)... 54.230.70.92, 54.230.70.39, 54.230.70.91, ...
# Connecting to d3s0tskafalll9.cloudfront.net (d3s0tskafalll9.cloudfront.net)|54.230.70.92|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 693719 (677K) [application/zip]
# Saving to: ‘kaggle-kakr-housing-data.zip’
#
# kaggle-kakr-housing 100%[===================>] 677.46K  1.97MB/s    in 0.3s
#
# 2026-06-07 07:57:01 (1.97 MB/s) - ‘kaggle-kakr-housing-data.zip’ saved [693719/693719]
#
# Archive:  kaggle-kakr-housing-data.zip
#   inflating: ./data/sample_submission.csv
#   inflating: ./data/test.csv
#   inflating: ./data/train.csv
